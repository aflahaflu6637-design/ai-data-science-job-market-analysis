# %% [markdown]
# # AI & Data Science Job Market Analysis
#
# ## Dataset Overview and Business Understanding
#
# ### Objective
#
# The objective of this notebook is to understand the AI & Data Science Job Market dataset and perform initial profiling before data cleaning and analysis.
#
# ### Business Understanding
#
# The AI and Data Science industry is growing rapidly across different countries, industries, and company types.
#
# This dataset contains information about AI-related job postings, including job titles, salaries, experience levels, locations, company characteristics, and work arrangements.
#
# The goal of this project is to identify patterns in hiring trends, salary distributions, experience requirements, and factors that influence compensation in the AI job market.
#
# ### Tasks
#
# - Load dataset
# - Perform initial profiling
# - Understand data structure
# - Identify data types
# - Analyze missing values
# - Create Data Quality Issue Log

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
df = pd.read_csv("../data/raw/ai_jobs.csv")

print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %% [markdown]
# ## Dataset Preview

# %%
df.head()
# Out:
#          job_id                  job_title  company_type    industry  \
# 0  0IFD0TVBDIVU             MLOps Engineer  Research Lab   Education
# 1  ZMF8MDD4V30T               Data Analyst       Startup   Education
# 2  CX1945NQ4FMY             MLOps Engineer  Research Lab        Tech
# 3  QJ7YHL1C32OC          Applied Scientist  Research Lab  Healthcare
# 4  F0T0PVN9ER14  Machine Learning Engineer  Research Lab     Finance
#
#      country    city remote_type experience_level  min_experience_years  \
# 0  Australia  Remote      Remote            Entry                     0
# 1    Germany  Remote      Remote            Entry                     0
# 2     Canada  Remote      Remote           Senior                     5
# 3  Australia  Remote      Remote            Entry                     0
# 4  Australia  Sydney      Hybrid              Mid                     2
#
#    salary_min_usd  salary_max_usd employment_type  posted_year company_size
# ...

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                50000 non-null  object
#  1   job_title             50000 non-null  object
#  2   company_type          50000 non-null  object
#  3   industry              50000 non-null  object
#  4   country               50000 non-null  object
#  5   city                  50000 non-null  object
#  6   remote_type           50000 non-null  object
#  7   experience_level      50000 non-null  object
#  8   min_experience_years  50000 non-null  int64
#  9   salary_min_usd        50000 non-null  int64
#  10  salary_max_usd        50000 non-null  int64
#  11  employment_type       50000 non-null  object
#  12  posted_year           50000 non-null  int64
#  13  company_size          50000 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#        min_experience_years  salary_min_usd  salary_max_usd   posted_year
# count          50000.000000    50000.000000    50000.000000  50000.000000
# mean               2.335500   100871.434320   120858.350740   2022.996360
# std                2.054172    37043.446641    37531.386484      2.001286
# min                0.000000    50000.000000    65000.000000   2020.000000
# 25%                0.000000    61287.000000    83739.000000   2021.000000
# 50%                2.000000    97505.000000   117604.000000   2023.000000
# 75%                5.000000   143730.500000   161348.750000   2025.000000
# max                5.000000   154999.000000   180000.000000   2026.000000

# %% [markdown]
# ## Unique Values Per Column

# %%
df.nunique()
# Out:
# job_id                  50000
# job_title                   6
# company_type                3
# industry                    5
# country                     6
# city                       24
# remote_type                 3
# experience_level            3
# min_experience_years        3
# salary_min_usd          30192
# salary_max_usd          36463
# employment_type             1
# posted_year                 7
# company_size                3
# dtype: int64

# %% [markdown]
# ## Column Type Identification

# %%
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

categorical_cols = df.select_dtypes(include=["object"]).columns

print("Numerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# Index(['min_experience_years', 'salary_min_usd', 'salary_max_usd',
#        'posted_year'],
#       dtype='object')
#
# Categorical Columns:
# Index(['job_id', 'job_title', 'company_type', 'industry', 'country', 'city',
#        'remote_type', 'experience_level', 'employment_type', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# job_id                  0
# job_title               0
# company_type            0
# industry                0
# country                 0
# city                    0
# remote_type             0
# experience_level        0
# min_experience_years    0
# salary_min_usd          0
# salary_max_usd          0
# employment_type         0
# posted_year             0
# company_size            0
# dtype: int64

# %% [markdown]
# # Data Quality Issue Log
#
# ## Findings
#
# 1. Dataset contains 50,000 records and 14 columns.
#
# 2. No missing values were found in any column.
#
# 3. Numerical columns:
#    - min_experience_years
#    - salary_min_usd
#    - salary_max_usd
#    - posted_year
#
# 4. Categorical columns:
#    - job_id
#    - job_title
#    - company_type
#    - industry
#    - country
#    - city
#    - remote_type
#    - experience_level
#    - employment_type
#    - company_size
#
# 5. job_id contains 50,000 unique values and can be treated as an identifier.
#
# 6. employment_type contains only one unique value and may not provide useful analytical information.
#
# 7. No immediate data quality issues detected at this stage.

# %% [markdown]
# # Day 1 Summary
#
# - Understood business problem and dataset structure.
# - Loaded and inspected dataset.
# - Identified numerical and categorical variables.
# - Performed missing value analysis.
# - Created Data Quality Issue Log.
# - Dataset is ready for cleaning and preprocessing in Day 2.
