# %% [markdown]
# # Day 5 — Final Insights & Project Summary

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/processed/final_cleaned_day4.csv")

print("Dataset Shape:", df.shape)

df.head()
# Out:
# Dataset Shape: (50000, 20)
#          job_id                  job_title  company_type    industry  \
# 0  0IFD0TVBDIVU             MLOps Engineer  Research Lab   Education
# 1  ZMF8MDD4V30T               Data Analyst       Startup   Education
# 2  CX1945NQ4FMY             MLOps Engineer  Research Lab        Tech
# 3  QJ7YHL1C32OC          Applied Scientist  Research Lab  Healthcare
# 4  F0T0PVN9ER14  Machine Learning Engineer  Research Lab     Finance
#
#      country    city remote_type experience_level  min_experience_years  \
# 0  Australia  Remote      Remote            Entry                     0
# 1    Germany  Remote      Remote            Entry                     0
# 2     Canada  Remote      Remote           Senior                     5
# 3  Australia  Remote      Remote            Entry                     0
# 4  Australia  Sydney      Hybrid              Mid                     2
#
#    salary_min_usd  salary_max_usd employment_type  posted_year company_size  \
# ...

# %% [markdown]
# # Executive Summary
#
# This notebook summarizes the final findings from the AI Data Science Job Market Analysis project.
#
# Objectives:
# - Summarize key insights
# - Present segment findings
# - Review data quality
# - Prepare project conclusions

# %%
print("Total Records:", len(df))
print("Total Columns:", len(df.columns))
print("Countries:", df["country"].nunique())
print("Industries:", df["industry"].nunique())
print("Job Titles:", df["job_title"].nunique())
print("Company Types:", df["company_type"].nunique())
# Out:
# Total Records: 50000
# Total Columns: 20
# Countries: 6
# Industries: 5
# Job Titles: 6
# Company Types: 3

# %% [markdown]
# ## Dataset Overview Findings
#
# - Dataset contains 50,000 AI/Data Science job records.
# - Multiple countries and industries are represented.
# - Dataset was cleaned and prepared during Days 1–4.

# %% [markdown]
# # Top 10 Insights

# %% [markdown]
# ## Insight 1
# The dataset contains 50,000 AI and Data Science job postings across 6 countries.
#
# ## Insight 2
# Senior-level positions command significantly higher salaries than Entry and Mid-level positions.
#
# ## Insight 3
# Salary strongly increases with required years of experience.
#
# ## Insight 4
# Salary minimum and salary maximum have a very strong positive correlation.
#
# ## Insight 5
# Remote, Hybrid, and Onsite jobs have similar salary distributions.
#
# ## Insight 6
# No statistically significant salary difference was found between Remote and Onsite jobs (T-Test).
#
# ## Insight 7
# No statistically significant salary difference was found among Remote, Hybrid, and Onsite jobs (ANOVA).
#
# ## Insight 8
# Experience level and remote work type are not significantly associated (Chi-Square Test).
#
# ## Insight 9
# AI/Data Science job demand remained relatively stable across the analyzed years.
#
# ## Insight 10
# The dataset contained no missing values, duplicate records, or detected outliers after preprocessing.

# %% [markdown]
# # Segment Findings

# %% [markdown]
# ## Experience Level Segment
#
# - Senior roles have the highest salary range.
# - Mid-level roles occupy the middle salary band.
# - Entry-level roles receive the lowest salaries.
#
# ## Country Segment
#
# - Job opportunities are distributed relatively evenly across all countries.
# - UK shows the highest count of postings, but differences are small.
#
# ## Industry Segment
#
# - Technology-related industries consistently offer competitive salaries.
# - Demand is spread across multiple sectors including Healthcare, Finance, Education, and Tech.
#
# ## Remote Work Segment
#
# - Remote, Hybrid, and Onsite jobs exhibit similar salary patterns.
# - Work arrangement alone does not appear to strongly influence compensation.

# %% [markdown]
# # Data Quality Review

# %% [markdown]
# ## Data Quality Findings
#
# During preprocessing and cleaning:
#
# - No missing values were found in any column.
# - No duplicate records were detected.
# - No significant outliers were detected using the IQR method.
# - Categorical variables were standardized.
# - Datatypes were validated and corrected where necessary.
#
# Overall, the dataset was found to be clean and suitable for analysis.

# %% [markdown]
# # Final Conclusion
#
# This project analyzed 50,000 AI and Data Science job postings across multiple countries and industries.
#
# Major findings include:
#
# - Experience level is the strongest driver of salary.
# - Senior professionals receive significantly higher compensation.
# - Remote work arrangements do not significantly impact salary levels.
# - AI and Data Science demand remained stable across the analyzed years.
# - The dataset demonstrated strong consistency and high data quality.
#
# The project successfully completed data cleaning, exploratory analysis, statistical testing, feature engineering, and final business insight generation.
